# %% [markdown]
# # Aprendizaje Automático - Proyecto Final
# ## Regresión logística

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

import scipy.optimize as opt

pd.options.mode.chained_assignment = None

import plot_functions as plt_f

import os

# %% [markdown]
# Leemos el archivo:

# %%
dt = pd.read_csv("heart.csv")
dt.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# Hacemos una traducción al español de los valores del dataset.

# %%
dt.columns = ['edad', 'sexo', 'dolor', 
              'tension', 'colesterol', 'glucemia', 
              'ecg', 'frec_cardiaca', 'angina_ej', 
              'depresion_st', 'pendiente_st', 
              'num_valvulas', 'test_talio', 
              'enfermedad']

dt.head()
# Out:
#    edad  sexo  dolor  tension  colesterol  glucemia  ecg  frec_cardiaca  \
# 0    63     1      3      145         233         1    0            150
# 1    37     1      2      130         250         0    1            187
# 2    41     0      1      130         204         0    0            172
# 3    56     1      1      120         236         0    1            178
# 4    57     0      0      120         354         0    1            163
#
#    angina_ej  depresion_st  pendiente_st  num_valvulas  test_talio  enfermedad
# 0          0           2.3             0             0           1           1
# 1          0           3.5             0             0           2           1
# 2          0           1.4             2             0           2           1
# 3          0           0.8             2             0           2           1
# 4          1           0.6             2             0           2           1

# %% [markdown]
# ## Preparamos el modelo para la regresión logística

# %%
# Sigmoide
def g(z):
    return 1 / (1 + np.exp(-z))

def coste(Theta, X, y):
    m = np.shape(X)[0]
    #auxTheta = np.reshape(Theta, (np.shape(Theta)[0], 1))
    Aux = (np.log(g(X @ Theta))).T @ y
    Aux += (np.log(1 - g(X @ Theta))).T @ (1 - y)
    return -Aux / m

def gradiente(Theta, X, y):
    m = np.shape(X)[0]
    #auxTheta = np.reshape(Theta, (np.shape(Theta)[0], 1))
    Aux = X.T @ (g(X @ Theta) - y)
    return Aux / m

# %%
def coste_reg(Theta, X, y, Lambda):
    m = np.shape(X)[0]
    Aux = (np.log(g(X @ Theta))).T @ y
    Aux += (np.log(1 - g(X @ Theta))).T @ (1 - y)
    Cost = -Aux / m
    Regcost = (Lambda / (2 * m)) * sum(Theta ** 2)
    return Cost + Regcost 

def gradiente_reg(Theta, X, y, Lambda):
    m = np.shape(X)[0]
    Aux = X.T @ (g(X @ Theta) - y)
    Grad = Aux / m
    theta_aux = Theta
    theta_aux[0] = 0.0
    Grad = Grad + (Lambda / m) * theta_aux
    return Grad

# %%
x_attribute0 = "edad"
x_attribute1 = 'tension'
y_attribute = 'enfermedad'

attributeList = dt.columns.values.tolist()
attributeList.remove(x_attribute0)
attributeList.remove(x_attribute1)

y = dt[y_attribute].values
y = np.reshape(y, (np.shape(y)[0], 1)).astype(float).ravel()

X_data = dt.drop(attributeList, axis = 1)
X_data.to_csv('X_data.csv', header=False, index=False)
X_data = pd.read_csv('X_data.csv', header=None)
os.remove('X_data.csv')

X = X_data.values

m = np.shape(X)[0]
X_ones = np.hstack([np.ones([m, 1]), X])
n = np.shape(X_ones)[1]

Theta = np.zeros(n)

result = opt.fmin_tnc(func=coste, x0=Theta, fprime=gradiente, args=(X_ones, y))
theta_opt = result[0]

plt_f.plot_frontier(theta_opt, X, y)
# plot_frontier_3D(theta_opt, X, Y)
# accuracy_percentage(theta_opt, X_ones, Y)

# %%
def LogisticRegresion(dt, x_attribute0, x_attribute1, y_attribute):
    attributeList = dt.columns.values.tolist()
    attributeList.remove(x_attribute0)
    attributeList.remove(x_attribute1)

    y = dt[y_attribute].values
    y = np.reshape(y, (np.shape(y)[0], 1)).astype(float).ravel()
    
    X_data = dt.drop(attributeList, axis = 1)
    X_data.to_csv('X_data.csv', header=False, index=False)
    X_data = pd.read_csv('X_data.csv', header=None)
    os.remove('X_data.csv')
    
    X = X_data.values
    
    m = np.shape(X)[0]
    X_ones = np.hstack([np.ones([m, 1]), X])
    n = np.shape(X_ones)[1]

    Theta = np.zeros(n)
    
    result = opt.fmin_tnc(func=coste, x0=Theta, fprime=gradiente, args=(X_ones, y))
    theta_opt = result[0]
    
    return plt_f.plot_frontier(theta_opt, X, y)
    # plot_frontier_3D(theta_opt, X, Y)
    # accuracy_percentage(theta_opt, X_ones, Y)

# %%
LogisticRegression(dt, 'edad', 'tension', 'enfermedad')
# Out:
# LogisticRegression(C='enfermedad', class_weight=None, dual='edad',
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1,
#           penalty=     edad  sexo  dolor  tension  colesterol  glucemia  ecg  frec_cardiaca  \
# 0      63     1      3      145         233         1    0            150
# 1      37     1      2      130         250         0    1            187
# 2      41     0      1      130         204         0    0   ...0
# 299           0
# 300           0
# 301           0
# 302           0
#
# [303 rows x 14 columns],
#           random_state=None, solver='liblinear', tol='tension', verbose=0,
#           warm_start=False)
